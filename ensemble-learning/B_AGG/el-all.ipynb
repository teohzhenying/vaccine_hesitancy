# %%
# import statements
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("booster_normalized.csv")
target = df["AgreeSubsequentBooster"]
features = df.drop("AgreeSubsequentBooster",axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %% [markdown]
# __Random Forest__

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics

best_n_estimator = 1
best_scores = 0

for n in range(1, 20):
    # Random Forest Bagging
    model_bagging_rf = BaggingClassifier(estimator=RandomForestClassifier(max_features="log2", bootstrap=False), n_estimators=n, random_state=7)
    
    # Cross-validation
    print("Model: Random Forest")
    scores_rf = cross_val_score(model_bagging_rf, x_train, y_train, cv=5, scoring='accuracy')
    print("Accuracy scores for each fold: ", scores_rf)
    print("Mean Accuracy (Validation):", scores_rf.mean())
    print("-" * 50)
    
    # find the best n_estimator
    if scores_rf.mean() > best_scores:
        best_scores = scores_rf.mean()
        best_n_estimator = n
    
print("Best n estimator is: ", best_n_estimator, " with score ", best_scores)

# Test set evaluation
model_bagging_rf = BaggingClassifier(estimator=RandomForestClassifier(max_features="log2", bootstrap=False), n_estimators=best_n_estimator, random_state=7)
model_bagging_rf.fit(x_train, y_train)
test_predict_rf = model_bagging_rf.predict(x_test)
print("Random Forest Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_rf))
print("=" * 50)
# Out:
# Model: Random Forest
# Accuracy scores for each fold:  [0.65625    0.8125     0.59375    0.75       0.70967742]
# Mean Accuracy (Validation): 0.7044354838709678
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.59375    0.8125     0.625      0.71875    0.74193548]
# Mean Accuracy (Validation): 0.6983870967741936
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.59375    0.84375    0.625      0.6875     0.74193548]
# Mean Accuracy (Validation): 0.6983870967741936
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.5625     0.8125     0.625      0.71875    0.70967742]
# Mean Accuracy (Validation): 0.6856854838709678
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.53125    0.8125     0.625      0.625      0.74193548]
# Mean Accuracy (Validation): 0.6671370967741936
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.59375    0.8125     0.6875     0.65625    0.77419355]
# Mean Accuracy (Validation): 0.7048387096774194
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.59375    0.8125     0.65625    0.65625    0.70967742]
# Mean Accuracy (Validation): 0.6856854838709678
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.59375    0.8125     0.65625    0.625      0.70967742]
# Mean Accuracy (Validation): 0.6794354838709677
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.59375    0.8125     0.65625    0.65625    0.74193548]
# Mean Accuracy (Validation): 0.6921370967741935
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.625      0.8125     0.65625    0.6875     0.74193548]
# Mean Accuracy (Validation): 0.7046370967741936
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.625      0.8125     0.65625    0.65625    0.70967742]
# Mean Accuracy (Validation): 0.6919354838709678
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.625      0.8125     0.65625    0.65625    0.70967742]
# Mean Accuracy (Validation): 0.6919354838709678
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.625      0.8125     0.65625    0.65625    0.70967742]
# Mean Accuracy (Validation): 0.6919354838709678
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.625      0.8125     0.65625    0.6875     0.70967742]
# Mean Accuracy (Validation): 0.6981854838709678
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.625      0.8125     0.65625    0.6875     0.70967742]
# Mean Accuracy (Validation): 0.6981854838709678
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.625      0.8125     0.65625    0.6875     0.70967742]
# Mean Accuracy (Validation): 0.6981854838709678
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.65625    0.8125     0.625      0.65625    0.70967742]
# Mean Accuracy (Validation): 0.6919354838709678
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.65625    0.8125     0.65625    0.6875     0.70967742]
# Mean Accuracy (Validation): 0.7044354838709678
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.65625    0.8125     0.65625    0.65625    0.70967742]
# Mean Accuracy (Validation): 0.6981854838709678
# --------------------------------------------------
# Best n estimator is:  6  with score  0.7048387096774194
# Random Forest Bagging - Accuracy (Test): 0.675
# ==================================================

# %% [markdown]
# __Bagging - GNB__

# %%
# Import necessary libraries
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics

model_bagging_dt = BaggingClassifier(
    estimator=GaussianNB(),
    n_estimators=10,
    random_state=7
)

# Cross-validation
print("Model: GNB")
scores_nn = cross_val_score(model_bagging_dt, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold: ", scores_nn)
print("Mean Accuracy (Validation):", scores_nn.mean())
print("-" * 50)

# Test set evaluation
model_bagging_dt.fit(x_train, y_train)
test_predict_nn = model_bagging_dt.predict(x_test)
print("GNB Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_nn))
print("=" * 50)
# Out:
# Model: GNB
# Accuracy scores for each fold:  [0.5        0.46875    0.59375    0.46875    0.48387097]
# Mean Accuracy (Validation): 0.5030241935483871
# --------------------------------------------------
# GNB Bagging - Accuracy (Test): 0.425
# ==================================================

# %% [markdown]
# __Bagging - SVM poly__

# %%
# Import necessary libraries
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# SVC 
model_bagging_poly = BaggingClassifier(
    estimator=SVC(kernel="poly", C= 1, degree= 3, gamma= "auto"),
    n_estimators=5,
    random_state=7
)

# Cross-validation
print("Model: SVC poly")
scores_nn = cross_val_score(model_bagging_poly, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold: ", scores_nn)
print("Mean Accuracy (Validation):", scores_nn.mean())
print("-" * 50)

# Test set evaluation
model_bagging_poly.fit(x_train, y_train)
test_predict_nn = model_bagging_poly.predict(x_test)
print("SVC poly Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_nn))
print("=" * 50)
# Out:
# Model: SVC poly
# Accuracy scores for each fold:  [0.625      0.78125    0.71875    0.625      0.70967742]
# Mean Accuracy (Validation): 0.6919354838709678
# --------------------------------------------------
# SVC poly Bagging - Accuracy (Test): 0.675
# ==================================================

# %% [markdown]
# __Bagging - 2 hidden__

# %%
# Import necessary libraries
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# Neural Network with one hidden layer of 5 neurons
model_bagging_nn = BaggingClassifier(
    estimator=MLPClassifier(hidden_layer_sizes=(5,40), max_iter=10000, random_state=7),
    n_estimators=10,
    random_state=7
)

# Cross-validation
print("Model: Neural Network (2 hidden layer)")
scores_nn = cross_val_score(model_bagging_nn, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold: ", scores_nn)
print("Mean Accuracy (Validation):", scores_nn.mean())
print("-" * 50)

# Test set evaluation
model_bagging_nn.fit(x_train, y_train)
test_predict_nn = model_bagging_nn.predict(x_test)
print("Neural Network Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_nn))
print("=" * 50)
# Out:
# Model: Neural Network (2 hidden layer)
# Accuracy scores for each fold:  [0.6875     0.6875     0.625      0.8125     0.58064516]
# Mean Accuracy (Validation): 0.6786290322580645
# --------------------------------------------------
# Neural Network Bagging - Accuracy (Test): 0.575
# ==================================================

# %% [markdown]
# __Bagging - SVM sigmoid__

# %%
# Import necessary libraries
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# SVC 
model_bagging_sigmoid = BaggingClassifier(
    estimator=SVC(kernel="sigmoid", C= 10, gamma= "auto"),
    n_estimators=5,
    random_state=7
)

# Cross-validation
print("Model: SVC sigmoid")
scores_nn = cross_val_score(model_bagging_sigmoid, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold: ", scores_nn)
print("Mean Accuracy (Validation):", scores_nn.mean())
print("-" * 50)

# Test set evaluation
model_bagging_sigmoid.fit(x_train, y_train)
test_predict_nn = model_bagging_sigmoid.predict(x_test)
print("SVC sigmoid Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_nn))
print("=" * 50)
# Out:
# Model: SVC sigmoid
# Accuracy scores for each fold:  [0.6875     0.75       0.625      0.78125    0.70967742]
# Mean Accuracy (Validation): 0.7106854838709677
# --------------------------------------------------
# SVC sigmoid Bagging - Accuracy (Test): 0.575
# ==================================================

# %% [markdown]
# __Boosting__

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Define the Gradient Boosting classifier
gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# Cross-validation
cv_scores = cross_val_score(gbc, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold (CV): ", cv_scores)
print("Mean Accuracy (Validation): {:.4f}".format(cv_scores.mean()))
print("-" * 50)

# Fit the model on the full training data
gbc.fit(x_train, y_train)

# Evaluate the model on the test data
y_test_pred = gbc.predict(x_test)
accuracy = accuracy_score(y_test, y_test_pred)

# Print evaluation metrics
print(f'Accuracy (Test): {accuracy:.4f}')
print('Confusion Matrix:')
print(confusion_matrix(y_test, y_test_pred))
print('Classification Report:')
print(classification_report(y_test, y_test_pred))
print("=" * 50)
# Out:
# Accuracy scores for each fold (CV):  [0.53125    0.75       0.625      0.59375    0.70967742]
# Mean Accuracy (Validation): 0.6419
# --------------------------------------------------
# Accuracy (Test): 0.7250
# Confusion Matrix:
# [[ 6  8]
#  [ 3 23]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.43      0.52        14
#            1       0.74      0.88      0.81        26
#
#     accuracy                           0.72        40
#    macro avg       0.70      0.66      0.66        40
# weighted avg       0.72      0.72      0.71        40
#
# ==================================================

# %% [markdown]
# __XGBoost__

# %%
import xgboost as xgb
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import numpy as np

# Define the XGBoost classifier
xgb_clf = xgb.XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# Cross-validation
cv_scores = cross_val_score(xgb_clf, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold (CV): ", cv_scores)
print("Mean Accuracy (Validation): {:.4f}".format(cv_scores.mean()))
print("-" * 50)

# Fit the model on the full training data
xgb_clf.fit(x_train, y_train)

# Evaluate the model on the test data
y_test_pred = xgb_clf.predict(x_test)
accuracy = accuracy_score(y_test, y_test_pred)

# Print evaluation metrics
print(f'Accuracy (Test): {accuracy:.4f}')
print('Confusion Matrix:')
print(confusion_matrix(y_test, y_test_pred))
print('Classification Report:')
print(classification_report(y_test, y_test_pred))
print("=" * 50)
# Out:
# Accuracy scores for each fold (CV):  [0.4375     0.71875    0.625      0.59375    0.67741935]
# Mean Accuracy (Validation): 0.6105
# --------------------------------------------------
# Accuracy (Test): 0.6500
# Confusion Matrix:
# [[ 4 10]
#  [ 4 22]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.29      0.36        14
#            1       0.69      0.85      0.76        26
#
#     accuracy                           0.65        40
#    macro avg       0.59      0.57      0.56        40
# weighted avg       0.62      0.65      0.62        40
#
# ==================================================
