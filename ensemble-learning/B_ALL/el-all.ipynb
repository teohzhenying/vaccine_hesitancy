# %%
# import statements
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("normalized_min-max.csv")
target = df["AgreeSubsequentBooster"]
features = df.drop("AgreeSubsequentBooster",axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %% [markdown]
# __Random Forest__

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics

best_n_estimator = 1
best_scores = 0

for n in range(1, 20):
    # Random Forest Bagging
    model_bagging_rf = BaggingClassifier(estimator=RandomForestClassifier(max_features="log2", bootstrap=False), n_estimators=n, random_state=7)
    
    # Cross-validation
    print("Model: Random Forest")
    scores_rf = cross_val_score(model_bagging_rf, x_train, y_train, cv=5, scoring='accuracy')
    print("Accuracy scores for each fold: ", scores_rf)
    print("Mean Accuracy (Validation):", scores_rf.mean())
    print("-" * 50)
    
    # find the best n_estimator
    if scores_rf.mean() > best_scores:
        best_scores = scores_rf.mean()
        best_n_estimator = n
    
print("Best n estimator is: ", best_n_estimator, " with score ", best_scores)

# Test set evaluation
model_bagging_rf = BaggingClassifier(estimator=RandomForestClassifier(max_features="log2", bootstrap=False), n_estimators=best_n_estimator, random_state=7)
model_bagging_rf.fit(x_train, y_train)
test_predict_rf = model_bagging_rf.predict(x_test)
print("Random Forest Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_rf))
print("=" * 50)
# Out:
# Model: Random Forest
# Accuracy scores for each fold:  [0.69642857 0.71428571 0.69642857 0.71428571 0.75      ]
# Mean Accuracy (Validation): 0.7142857142857142
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.78571429 0.73214286 0.69642857 0.73214286 0.75      ]
# Mean Accuracy (Validation): 0.7392857142857143
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.78571429 0.73214286 0.69642857 0.75       0.75      ]
# Mean Accuracy (Validation): 0.7428571428571429
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.76785714 0.71428571 0.66071429 0.76785714 0.76785714]
# Mean Accuracy (Validation): 0.7357142857142857
# --------------------------------------------------
# Model: Random Forest
# Accuracy scores for each fold:  [0.76785714 0.73214286 0.66071429 0.75       0.76785714]
# ...

# %% [markdown]
# __Bagging - Decision Tree__

# %%
# Import necessary libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# Neural Network with one hidden layer of 5 neurons
model_bagging_dt = BaggingClassifier(
    estimator=DecisionTreeClassifier(max_depth=5, criterion="entropy", random_state=20),
    n_estimators=10,
    random_state=7
)

# Cross-validation
print("Model: Decision tree")
scores_nn = cross_val_score(model_bagging_dt, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold: ", scores_nn)
print("Mean Accuracy (Validation):", scores_nn.mean())
print("-" * 50)

# Test set evaluation
model_bagging_dt.fit(x_train, y_train)
test_predict_nn = model_bagging_dt.predict(x_test)
print("Decision tree Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_nn))
print("=" * 50)
# Out:
# Model: Decision tree
# Accuracy scores for each fold:  [0.71428571 0.73214286 0.71428571 0.73214286 0.66071429]
# Mean Accuracy (Validation): 0.7107142857142856
# --------------------------------------------------
# Decision tree Bagging - Accuracy (Test): 0.7428571428571429
# ...

# %% [markdown]
# __Bagging - MLP 1-hidden__

# %%
# Import necessary libraries
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# Neural Network with one hidden layer of 5 neurons
model_bagging_nn = BaggingClassifier(
    estimator=MLPClassifier(hidden_layer_sizes=(65,), max_iter=10000, random_state=7),
    n_estimators=10,
    random_state=7
)

# Cross-validation
print("Model: Neural Network (1 hidden layer)")
scores_nn = cross_val_score(model_bagging_nn, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold: ", scores_nn)
print("Mean Accuracy (Validation):", scores_nn.mean())
print("-" * 50)

# Test set evaluation
model_bagging_nn.fit(x_train, y_train)
test_predict_nn = model_bagging_nn.predict(x_test)
print("Neural Network Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_nn))
print("=" * 50)
# Out:
# Model: Neural Network (1 hidden layer)
# Accuracy scores for each fold:  [0.69642857 0.73214286 0.69642857 0.75       0.75      ]
# Mean Accuracy (Validation): 0.725
# --------------------------------------------------
# Neural Network Bagging - Accuracy (Test): 0.7142857142857143
# ...

# %% [markdown]
# __Bagging - SVM poly__

# %%
# Import necessary libraries
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# SVC 
model_bagging_poly = BaggingClassifier(
    estimator=SVC(kernel="poly", C= 10, degree= 3, gamma= "scale"),
    n_estimators=5,
    random_state=7
)

# Cross-validation
print("Model: SVC poly")
scores_nn = cross_val_score(model_bagging_poly, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold: ", scores_nn)
print("Mean Accuracy (Validation):", scores_nn.mean())
print("-" * 50)

# Test set evaluation
model_bagging_poly.fit(x_train, y_train)
test_predict_nn = model_bagging_poly.predict(x_test)
print("SVC poly Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_nn))
print("=" * 50)
# Out:
# Model: SVC poly
# Accuracy scores for each fold:  [0.73214286 0.73214286 0.71428571 0.76785714 0.67857143]
# Mean Accuracy (Validation): 0.725
# --------------------------------------------------
# SVC poly Bagging - Accuracy (Test): 0.6571428571428571
# ...

# %% [markdown]
# __Bagging - SVM rbf__

# %%
# Import necessary libraries
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# SVC 
model_bagging_rbf = BaggingClassifier(
    estimator=SVC(kernel="rbf", C= 1, gamma= "scale"),
    n_estimators=5,
    random_state=7
)

# Cross-validation
print("Model: SVC poly")
scores_nn = cross_val_score(model_bagging_rbf, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold: ", scores_nn)
print("Mean Accuracy (Validation):", scores_nn.mean())
print("-" * 50)

# Test set evaluation
model_bagging_rbf.fit(x_train, y_train)
test_predict_nn = model_bagging_rbf.predict(x_test)
print("SVC poly Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_nn))
print("=" * 50)
# Out:
# Model: SVC poly
# Accuracy scores for each fold:  [0.75       0.76785714 0.69642857 0.75       0.78571429]
# Mean Accuracy (Validation): 0.75
# --------------------------------------------------
# SVC poly Bagging - Accuracy (Test): 0.7857142857142857
# ...

# %% [markdown]
# __Boosting__

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Define the Gradient Boosting classifier
gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# Cross-validation
cv_scores = cross_val_score(gbc, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold (CV): ", cv_scores)
print("Mean Accuracy (Validation): {:.4f}".format(cv_scores.mean()))
print("-" * 50)

# Fit the model on the full training data
gbc.fit(x_train, y_train)

# Evaluate the model on the test data
y_test_pred = gbc.predict(x_test)
accuracy = accuracy_score(y_test, y_test_pred)

# Print evaluation metrics
print(f'Accuracy (Test): {accuracy:.4f}')
print('Confusion Matrix:')
print(confusion_matrix(y_test, y_test_pred))
print('Classification Report:')
print(classification_report(y_test, y_test_pred))
print("=" * 50)
# Out:
# Accuracy scores for each fold (CV):  [0.64285714 0.71428571 0.64285714 0.76785714 0.71428571]
# Mean Accuracy (Validation): 0.6964
# --------------------------------------------------
# Accuracy (Test): 0.7429
# Confusion Matrix:
# [[23 14]
#  [ 4 29]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.62      0.72        37
#            1       0.67      0.88      0.76        33
#
#     accuracy                           0.74        70
#    macro avg       0.76      0.75      0.74        70
# weighted avg       0.77      0.74      0.74        70
#
# ...

# %% [markdown]
# __XGBoost__

# %%
import xgboost as xgb
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import numpy as np

# Define the XGBoost classifier
xgb_clf = xgb.XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# Cross-validation
cv_scores = cross_val_score(xgb_clf, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold (CV): ", cv_scores)
print("Mean Accuracy (Validation): {:.4f}".format(cv_scores.mean()))
print("-" * 50)

# Fit the model on the full training data
xgb_clf.fit(x_train, y_train)

# Evaluate the model on the test data
y_test_pred = xgb_clf.predict(x_test)
accuracy = accuracy_score(y_test, y_test_pred)

# Print evaluation metrics
print(f'Accuracy (Test): {accuracy:.4f}')
print('Confusion Matrix:')
print(confusion_matrix(y_test, y_test_pred))
print('Classification Report:')
print(classification_report(y_test, y_test_pred))
print("=" * 50)
# Out:
# Accuracy scores for each fold (CV):  [0.73214286 0.73214286 0.73214286 0.75       0.73214286]
# Mean Accuracy (Validation): 0.7357
# --------------------------------------------------
# Accuracy (Test): 0.8000
# Confusion Matrix:
# [[27 10]
#  [ 4 29]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.73      0.79        37
#            1       0.74      0.88      0.81        33
#
#     accuracy                           0.80        70
#    macro avg       0.81      0.80      0.80        70
# weighted avg       0.81      0.80      0.80        70
#
# ...
